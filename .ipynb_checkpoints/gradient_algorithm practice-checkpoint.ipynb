# %%
import numpy as np
from sklearn import linear_model
from scipy.stats import linregress
import pandas as pd
import math

# %%
def gradient(x,y):
    m_curr,intercept=0,0
    iter=100000
    learning_rate=0.0001
    prev_cost=0
    # reg=linear_model.LinearRegression()
    # reg.fit([x],y)
    print(linregress(x, y))
    #print("Expected Slope {} intercept {}".format(reg.coef_,reg.intercept_))
    for i in range(iter):s
        y_predicted=m_curr*x+intercept
        m_dirv=-((2/len(x))*sum(x*(y-y_predicted)))
        intercept_dirv=-((2/len(x))*sum(y-y_predicted))
        m_curr=m_curr-learning_rate*m_dirv
        intercept=intercept-learning_rate*intercept_dirv
        cost_function=1/len(x)*(sum([val**2 for val in y-y_predicted]))
        #print("Slope m {} intercept {} cost {} iter {} ".format(m_curr,intercept,cost_function,i))
        if(math.isclose(prev_cost,cost_function,rel_tol=1e-09)):
            print("no of iteration took {} prev_cost {} cur_cost {}".format(i,prev_cost,cost_function))
            break
        else:
            print("Slope m {} intercept {} cost {} iter {} ".format(m_curr,intercept,cost_function,i))
            
            #prev_cost=cost_function
# Out:
#   File "<ipython-input-51-edb76997ce9c>", line 11
#     y_predicted=m_curr*x+intercept
#     ^
# IndentationError: unexpected indent

# %%
df=pd.read_csv("test_scores.csv")
df
# Out:
#      name  math  cs
# 0   david    92  98
# 1   laura    56  68
# 2  sanjay    88  81
# 3     wei    70  80
# 4    jeff    80  83
# 5   aamir    49  52
# 6  venkat    65  66
# 7   virat    35  30
# 8  arthur    66  68
# 9    paul    67  73

# %%
gradient(df.math,df.cs)
# Out:
# LinregressResult(slope=1.0177362378569328, intercept=1.9152193111569034, rvalue=0.9481857126795193, pvalue=2.9615125513279844e-05, stderr=0.12056931108283597, intercept_stderr=8.295659277043695)
# Slope m 19.783600000000003 intercept 0.2796 cost 5199.1 iter 0
# Slope m 19.783600000000003 intercept 0.2796 cost 5199.1 iter 0
# Slope m -335.1297587200002 intercept -4.728096320000001 cost 1663047.8675860171 iter 1
# Slope m -335.1297587200002 intercept -4.728096320000001 cost 1663047.8675860171 iter 1
# Slope m 6031.9342997386275 intercept 85.11708759526404 cost 535217407.45495206 iter 2
# Slope m 6031.9342997386275 intercept 85.11708759526404 cost 535217407.45495206 iter 2
# Slope m -108191.7332859175 intercept -1526.6766256452784 cost 172251878290.197 iter 3
# Slope m -108191.7332859175 intercept -1526.6766256452784 cost 172251878290.197 iter 3
# Slope m 1940954.6398105891 intercept 27388.54081485446 cost 55436745729521.01 iter 4
# ...
